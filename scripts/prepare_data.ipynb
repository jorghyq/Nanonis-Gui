# %%
import pandas as pd
from ast import literal_eval
import sys
import matplotlib.pyplot as plt
# %pylab inline
import numpy as np
from skimage.transform import resize
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv('/home/jorghyq/Dropbox/test.csv', converters={'process':literal_eval},index_col=0)
data2 = pd.read_csv('/home/jorghyq/Dropbox/test2.csv', converters={'process':literal_eval},index_col=0)

# %%
data2['quality'] = data['quality']
data2['type'] = data['type']
data2['flat'] = data['flat']
data2['good'] = data['good']
data2['read'] = data['read']
data2['fullpath'] = data['fullpath']
data2['process'] = data['process']
data2.to_csv('/home/jorghyq/Dropbox/test2.csv')

# %%
data2
# Out:
#                        filename  ftype  fformat  pixel1  pixel2  size1[nm]  \
# 0      A160401.095948-00001.sxm      2        0     512     512        100
# 1      A160401.102125-00002.sxm      2        0     512     512        100
# 2      A160401.104612-00003.sxm      2        0     512     512        100
# 3      A160401.105414-00004.sxm      2        0     512     512        100
# 4      A160401.105921-00005.sxm      2        0     512     512        100
# 5      A160401.111506-00006.sxm      2        0     512     512        100
# 6      A160401.113136-00007.sxm      2        0     512     512        100
# 7      A160401.115340-00008.sxm      2        0     512     512        100
# 8      A160401.115932-00009.sxm      2        0     512     512         20
# 9      A160401.121724-00010.sxm      2        0     512     512        100
# 10     A160401.141109-00011.sxm      2        0     512     512         50
# ...

# %%
data3 = data2

# %%
def convert_date(date):
    dd, mm, yy = date.split('.')
    return yy+mm+dd

def convert_time(time):
    hh, mm, ss = time.split(':')
    return hh+mm+ss

def convert_to_ts(date):
    return pd.Timestamp(date)

# %%
data2['weekday'] = data2['timestamp'].dt.dayofweek

# %%
data2['weekday']
# Out:
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
# 5        4
# 6        4
# 7        4
# 8        4
# 9        4
# 10       4
# 11       4
# 12       4
# 13       4
# 14       4
# 15       4
# 16       4
# 17       4
# 18       4
# 19       0
# 20       0
# 21       0
# 22       0
# 23       0
# 24       0
# 25       0
# 26       0
# 27       0
# 28       0
# 29       0
#         ..
# 29962    0
# 29963    0
# 29964    0
# 29965    0
# 29966    0
# 29967    0
# 29968    0
# 29969    0
# 29970    0
# 29971    0
# 29972    0
# 29973    0
# 29974    0
# 29975    0
# 29976    0
# 29977    0
# 29978    0
# 29979    0
# 29980    0
# 29981    0
# 29982    0
# 29983    0
# 29984    0
# 29985    0
# 29986    0
# 29987    0
# 29988    0
# 29989    0
# 29990    0
# 29991    0
# Name: weekday, dtype: int64

# %%
data2.to_csv('/home/jorghyq/Dropbox/test3.csv')
